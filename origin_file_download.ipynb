# %% [markdown]
# dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
# dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',

# %%
import copernicusmarine


copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2017/*',
    create_file_list='plankton_list2017.txt',
    output_directory='D:/Data/CMEMS',
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2018/*',
    create_file_list='plankton_list2018.txt',
    output_directory='D:/Data/CMEMS',
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2019/*',
    create_file_list='plankton_list2019.txt',
    output_directory='D:/Data/CMEMS',
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2020/*',
    create_file_list='plankton_list2020.txt',
    output_directory='D:/Data/CMEMS', 
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2021/*',
    create_file_list='plankton_list2021.txt',
    output_directory='D:/Data/CMEMS',
    # file_list='D:/Data/CMEMS/plankton_list2021aaa.txt',
    # force_download='True',
)


copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2022/*',
    create_file_list='plankton_list2022.txt',
    output_directory='D:/Data/CMEMS',
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    filter='*/2023/*',
    create_file_list='plankton_list2023.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2017/*',
    create_file_list='transp_list2017.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2018/*',
    create_file_list='transp_list2018.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2019/*',
    create_file_list='transp_list2019.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2020/*',
    create_file_list='transp_list2020.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2021/*',
    create_file_list='transp_list2021.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2022/*',
    create_file_list='transp_list2022.txt',
    output_directory='D:/Data/CMEMS',
    
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-transp_my_l3-multi-4km_P1D',
    filter='*/2023/*',
    create_file_list='transp_list2023.txt',
    output_directory='D:/Data/CMEMS',
)

# %%
copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    output_directory='D:/Data/CMEMS',
    filter='*/2021/*',
    force_download='True',
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    output_directory='D:/Data/CMEMS',
    filter='*/2022/*',
    force_download='True',
)

copernicusmarine.get(
    username='hwang36',
    password='Wang20010113@',
    dataset_id='cmems_obs-oc_glo_bgc-plankton_my_l3-multi-4km_P1D',
    output_directory='D:/Data/CMEMS',
    filter='*/2023/*',
    force_download='True',
)
