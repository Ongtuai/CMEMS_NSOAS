# %% [markdown]
# |           Product ID                  |空间分辨率|时间分辨率|Processing level|观测要素|
# |:-------------------------------------:|:-------:|:-------:|:--------------:|:-----:|
# |SST_GLO_SST_L4_NRT_OBSERVATIONS_010_001|5km x 5km|  Daily  |     Level 4    |  SST  |
#
# #### 全球范围的原始文件一天的大小为13MB左右

# %%
username = 'your_username'
password = 'your_password'

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2017/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2018/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2019/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2020/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2021/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2022/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2023/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2024/*",
    output_directory='D:/Data/CMEMS/MY',
)

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2",
    filter="*2025/*",
    output_directory='D:/Data/CMEMS/MY',
)
# Out:
# INFO - 2025-01-15T02:32:05Z - Selected dataset version: "default"
# INFO - 2025-01-15T02:32:05Z - Selected dataset part: "default"
# INFO - 2025-01-15T02:32:05Z - Listing files on remote server...
# 7it [00:05,  1.35it/s]
# ...
# INFO - 2025-01-15T02:37:16Z - Selected dataset version: "default"
# INFO - 2025-01-15T02:37:16Z - Selected dataset part: "default"
# INFO - 2025-01-15T02:37:16Z - Listing files on remote server...
# 7it [00:05,  1.25it/s]
# ...
# INFO - 2025-01-15T02:43:24Z - Selected dataset version: "default"
# INFO - 2025-01-15T02:43:24Z - Selected dataset part: "default"
# INFO - 2025-01-15T02:43:24Z - Listing files on remote server...
# 7it [00:07,  1.01s/it]
# ...
# INFO - 2025-01-15T02:48:42Z - Selected dataset version: "default"
# INFO - 2025-01-15T02:48:42Z - Selected dataset part: "default"
# INFO - 2025-01-15T02:48:42Z - Listing files on remote server...
# 7it [00:05,  1.25it/s]
# ...
# INFO - 2025-01-15T02:53:24Z - Selected dataset version: "default"
# ...

# %%
username = 'hwang36'
password = 'Wang20010113@'

import copernicusmarine
copernicusmarine.get(
    username=username,
    password=password,
    dataset_id="cmems_obs-sl_glo_phy-ssh_nrt_allsat-l4-duacs-0.125deg_P1D",
    filter="*_20250101_*",
    output_directory='D:/Data/CMEMS/test',
    no_directories=True,
)
# Out:
# INFO - 2025-01-21T08:49:16Z - Selected dataset version: "202411"
# INFO - 2025-01-21T08:49:16Z - Selected dataset part: "default"
# INFO - 2025-01-21T08:49:16Z - Listing files on remote server...
# 1it [00:01,  1.54s/it]
# ...

# %%
copernicusmarine.get?
# Out:
# Signature:
# copernicusmarine.get(
#     dataset_id: Optional[str] = None,
#     dataset_version: Optional[str] = None,
#     dataset_part: Optional[str] = None,
#     username: Optional[str] = None,
#     password: Optional[str] = None,
#     no_directories: bool = False,
#     output_directory: Union[pathlib.Path, str, NoneType] = None,
#     credentials_file: Union[pathlib.Path, str, NoneType] = None,
#     overwrite: bool = False,
#     request_file: Union[pathlib.Path, str, NoneType] = None,
#     filter: Optional[str] = None,
#     regex: Optional[str] = None,
#     file_list: Union[pathlib.Path, str, NoneType] = None,
#     create_file_list: Optional[str] = None,
#     index_parts: bool = False,
#     sync: bool = False,
#     sync_delete: bool = False,
#     skip_existing: bool = False,
#     dry_run: bool = False,
#     max_concurrent_requests: int = 15,
#     disable_progress_bar: bool = False,
#     staging: bool = False,
# ...
